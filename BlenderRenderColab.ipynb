# %%
blender_version = "3.2.0 aces" #@param ["3.2.0", "3.2.0 aces"]
blend_file_path = '/content/drive/MyDrive/Colab_Notebooks/BlenderFiles/aces_test.blendb' #@param {type: 'string'}
#@markdown ---
optix_enabled = True #@param {type:"boolean"}

# %%
gpu = !nvidia-smi --query-gpu=gpu_name --format=csv,noheader
print("Current GPU: " + gpu[0])

if gpu[0] == "Tesla K80" and optix_enabled:
  print("OptiX disabled because of unsupported GPU")
  optix_enabled = False

# %%
#Connect Google Drive to Google Colab
#=====================================
from google.colab import drive
drive.mount('/content/drive')

# %%
#Download Blender from Blender Repository. 
#Other Versions are here: https://download.blender.org/release/
# !wget https://download.blender.org/release/Blender3.0/blender-3.0.0-linux-x64.tar.xz
#=====================================
blender_url_dict = {
    '3.2.0'      : '',
    '3.2.0 aces' : '/content/drive/MyDrive/Colab_Notebooks/BlenderVersions/blender-aces-3.2.0-linux-x64.tar.xz',
}

# !cp blender_url_dict[blender_version] /content/blender-3.2.0-linux-x64.tar.xz

# !cp /content/drive/MyDrive/Colab_Notebooks/BlenderVersions/blender-aces-3.2.0-linux-x64.tar.xz /content/blender-3.2.0-linux-x64.tar.xz

# %%
#Unzip Blender 
#=====================================
# !tar xf blender-3.2.0-linux-x64.tar.xz

# %%
#Deletes the Default libtcmalloc-minimal4 version and installs the Ubuntu default version
import os
 
os.environ["LD_PRELOAD"] = ""
 
#Deletes wrong Version of libtcmalloc-minimal4
# !apt remove libtcmalloc-minimal4
#Installs correct version of libtcmalloc-minimal4
# !apt install libtcmalloc-minimal4
 
#Adds this library to the user environment
os.environ["LD_PRELOAD"] = "/usr/lib/x86_64-linux-gnu/libtcmalloc_minimal.so.4.3.0"

# %%
#Path of Blender File to be Rendered 
#===========================
# filename = '/content/drive/MyDrive/Colab_Notebooks/BlenderFiles/aces_test.blend'

# %%
# !./blender-3.2.0-linux-x64/blender -P 'Colab_Notebooks/BlenderFiles/gpu.py' -b $filename -noaudio -E 'CYCLES' --debug-all -o "/content/drive/MyDrive/Colab_Notebooks/render/aces_test_####" -s 160 -e 160 -a -F "PNG" -- --cycles-device CUDA
# !./blender-3.2.0-linux-x64/blender -P 'Colab_Notebooks/BlenderFiles/gpu.py' -b $blend_file_path -noaudio -E 'CYCLES' --debug-all -o "/content/drive/MyDrive/Colab_Notebooks/render/aces_test_####" -s 160 -e 160 -a -- --cycles-device CUDA

# %%
#Usar estos comandos para mover el archivo comprimido de Blender a Google Drive y después moverlo de nuevo a Google Colab para que no tengas que descargar Blender cada vez.
 
#Copiar el archivo comprimido de Blender a Google Drive
#=====================================
#!cp /content/blender-2.93.5-linux-x64.tar.xz /content/drive/MyDrive/Blender/blender-2.93.5-linux-x64.tar.xz
 
#Copiar el archivo comprimido de Blender desde Google Drive
#=====================================
#!cp /content/drive/MyDrive/Blender/blender-2.93.5-linux-x64.tar.xz /content/blender-2.93.5-linux-x64.tar.xz
